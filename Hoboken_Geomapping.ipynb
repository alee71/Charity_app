# %% [markdown]
# # Motivation
# Purpose was to create an interactive map, so we can easily identify customers based on the location and National Taxonomy of Exempt Entities (NTEE) Codes. The NtEE code is used by IRS to classify each tax exempt organization based on the main activity. You can find more information about this here: https://nccs.urban.org/publication/irs-activity-codes. I have also included address and phone numbers to help with navigation in the future. The scope of the project is to only focus on charities in Hoboken.

# %%
# Loading packages
from geopy.geocoders import Nominatim
import pandas as pd
import sqlalchemy as sa
from sqlalchemy import create_engine
import numpy as np
from geopy.extra.rate_limiter import RateLimiter

# %% [markdown]
# # Load Data

# %%
# Load the data that was cleaned based on the original open990 database.
query=''' SELECT *
FROM hoboken_phone_address'''
e = sa.create_engine(r'sqlite:///D:\Program_practices\Charity\open990database.db')
df= pd.read_sql_query(query, e)
df.head(5)
# Out:
#          ein                                           name_org  tax_yr  \
# 0  203671056                       Symposia Community Bookstore    2013
# 1  203671056                       Symposia Community Bookstore    2015
# 2  222209099                         STEVENS COOPERATIVE SCHOOL    2010
# 3  221763570  CHURCH TOWERS URBAN RENEWAL CORP C/O TOTAL PRO...    2013
# 4  136271999  ASSOCIATION OF THE GRADUATES OF THE COLUMBIA C...    2014
#
#                phone              website                         address  \
# 0  +1 (201) 963-0909                 None           510 Washington Street
# 1  +1 (201) 963-0909                 None           510 Washington Street
# 2  +1 (201) 792-3688  WWW.STEVENSCOOP.ORG               301 GARDEN STREET
# 3  +1 (201) 659-0604                 None                10 CHURCH TOWERS
# 4  +1 (201) 993-9480                 None  1015 WASHINGTON STREET UNIT 50
#
#   formation_yr  gross_receipts ntee_code_nccs  \
# 0         2007          192350            P29
# 1         2007          180066            P29
# 2         1949         5935065            B24
# 3         1965         4347916            S20
# 4         None          248122            B83
#
#                                ntee_description_nccs  voting_memb_ct  \
# 0                                       Thrift Shops               6
# 1                                       Thrift Shops               6
# 2                        Primary, Elementary Schools              15
# 3  Community, Neighborhood Development, Improveme...               2
# 4                   Student Sororities, Fraternities              14
#
#    employee_tot_ct volunteer_tot_ct  gross_receipts:1  rev_tot_curyr  \
# 0                2             None            192350         192350
# 1                0             None            180066         180066
# 2              118                0           5935065        5858009
# 3               33             None           4347916        4347916
# 4                0             None            248122         248122
#
#    rev_less_expense_curyr local_chapt
# 0                   -1498          no
# 1                   -1937          no
# 2                  276650          no
# 3                 -121051          no
# 4                   33713          no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175 entries, 0 to 174
# Data columns (total 17 columns):
# ein                       175 non-null int64
# name_org                  175 non-null object
# tax_yr                    175 non-null int64
# phone                     166 non-null object
# website                   93 non-null object
# address                   175 non-null object
# formation_yr              163 non-null object
# gross_receipts            175 non-null int64
# ntee_code_nccs            128 non-null object
# ntee_description_nccs     128 non-null object
# voting_memb_ct            175 non-null int64
# employee_tot_ct           175 non-null int64
# volunteer_tot_ct          108 non-null object
# gross_receipts:1          175 non-null int64
# rev_tot_curyr             175 non-null int64
# rev_less_expense_curyr    175 non-null int64
# local_chapt               175 non-null object
# dtypes: int64(8), object(9)
# memory usage: 23.4+ KB

# %% [markdown]
# # Data Cleaning
# The original database has multiple tax years. I will only be taking the most recent one, assuming that this is the address and phone number are up-to-date. What I have noticed based on previous work, however, is that NTEE code is sometimes not consistent. When it is not consistent, I took the most recent code. Most of the time, it seems like NTEE code was left out by human mistake and was left blank. In this case, I created a key for the NTEE code to be added based on previous tax return records using .fillna method.

# %%
query=''' SELECT *
FROM hoboken_merger'''

e = sa.create_engine(r'sqlite:///D:\Program_practices\Charity\open990database.db')
df_merg= pd.read_sql_query(query, e)
key=df_merg[['ein', 'ntee_code_nccs']]
#%%
df=pd.merge(df,key, on='ein', how='left')
df = df.drop_duplicates(subset='ein', keep="last")
df['ntee_code_nccs_x']=df['ntee_code_nccs_x'].fillna(df['ntee_code_nccs_y'])
df=df.drop(columns='ntee_code_nccs_y')
df.head(5)
# Out:
#            ein                            name_org  tax_yr              phone  \
# 11   226052626          STEVENS ALUMNI ASSOCIATION    2011  +1 (201) 216-5163
# 14   222891851                  Columbian Arms Inc    2015               None
# 64   223517040          HOBOKEN CHARTER SCHOOL INC    2016  +1 (201) 963-0222
# 96   221801849  HOPES COMMUNITY ACTION PARTNERSHIP    2016  +1 (855) 654-6737
# 107  200596839              Party With Purpose Inc    2014  +1 (201) 988-7175
#
#                          website                     address formation_yr  \
# 11   WWW.ALUMNI.STEVENS-TECH.EDU  CASTLE POINT ON THE HUDSON         1958
# 14                          None          514 MADISON STREET         1987
# 64             WWW.HOBOKENCS.ORG       713 WASHINGTON STREET         1997
# 96                 WWW.HOPES.ORG           301 GARDEN STREET         1964
# 107                         None                 PO Box 1045         2002
#
#      gross_receipts ntee_code_nccs_x      ntee_description_nccs  \
# 11           956073              B84        Alumni Associations
# 14           896454              L21  Public Housing Facilities
# 64          5346175             None                       None
# 96         16748872              S20                       None
# 107          183780              T31      Community Foundations
#
#      voting_memb_ct  employee_tot_ct volunteer_tot_ct  gross_receipts:1  \
# 11               25                0              300            956073
# 14                9                0             None            896454
# 64                9               76             None           5346175
# 96               17              307              788          16748872
# 107              22                0              100            183780
#
#      rev_tot_curyr  rev_less_expense_curyr local_chapt
# 11          705616                  -22150          no
# 14          -40166                  -40166          no
# 64         5346175                  276176          no
# 96        15513189                 1916145          no
# 107         183780                   55830          no

# %% [markdown]
# To plot this on a map, the address has to be converted into latitude and longitude. You can use Google API, but I used geopy.geocoders

# %%
locator = Nominatim(user_agent='myGeocoder')
geocode = RateLimiter(locator.geocode, min_delay_seconds=1)

# %%
df['address']=df['address']
df['address']=df['address'].str.title()
df['address']
# Out:
# 11                            Castle Point On The Hudson
# 14                                    514 Madison Street
# 64                                 713 Washington Street
# 96                                     301 Garden Street
# 107                                          Po Box 1045
# 110                                       308 Willow Ave
# 111                       25 Fifth Street The Fieldhouse
# 155                                    404 Hudson Street
# 177                               601-603 Jackson Street
# 213                                   1460 Garden Street
# 224                                      601 Park Avenue
# 232                              106 Hudson St 2Nd Floor
# 249                                    308 Willow Avenue
# 255                     C/O P Capra 51 Harrison St No 5D
# 259                                          Po Box 3296
# 265                                    301 Garden Street
# 278                                    301 Garden Street
# 293                                        251 10Th St B
# 294                             926 Castle Point Terrace
# 297                             700 First Street Room 1P
# 304                               Castle Point On Hudson
# 306                                    422 Willow Avenue
# 312                                     124 Grand Street
# 314                                713 Washington Street
# 316                                     124 Grand Street
# 321    1015 Washington Street Unit 50 C/O Paul Nesham...
# 329                                     121 River Street
# 332                                   50 Harrison Street
# 335                               1005 Washington Street
# 337                                    301 Garden Street
# 341                              1115 Willow Ave Ste 512
# 344                                  1408 Clinton Street
# 346                                 497 Observer Highway
# 347                             806 Castle Point Terrace
# 349                                           Po Box 865
# 351                          36 Newark Street Rm/Ste 501
# 356                                     10 Church Towers
# 358                                     121 River Street
# 360                                 123 Jefferson Avenue
# 362                                   411 Clinton Street
# 364                                510 Washington Street
# Name: address, dtype: object

# %% [markdown]
# As you can see, the detailed information about the building (eg, unit, room, and floor numbers) is included. Since we don't need these numbers to locate each organization and these numbers will likely interfere with geocoding, these will be removed below. In addition, some of the addresses are listed as PO box, and they will not be coded properly. Thus, adopting the name of the company will be better.

# %%
import re
df['address_code']=df.apply(lambda df: df['name_org'] if 'Po Box' in df['address'] else df['address'], axis=1)
df['address_code']=df['address_code'].str.title()
df['address_code']
# Out:
# 11                            Castle Point On The Hudson
# 14                                    514 Madison Street
# 64                                 713 Washington Street
# 96                                     301 Garden Street
# 107                               Party With Purpose Inc
# 110                                       308 Willow Ave
# 111                       25 Fifth Street The Fieldhouse
# 155                                    404 Hudson Street
# 177                               601-603 Jackson Street
# 213                                   1460 Garden Street
# 224                                      601 Park Avenue
# 232                              106 Hudson St 2Nd Floor
# 249                                    308 Willow Avenue
# 255                     C/O P Capra 51 Harrison St No 5D
# 259                        Hoboken Historical Museum Inc
# 265                                    301 Garden Street
# 278                                    301 Garden Street
# 293                                        251 10Th St B
# 294                             926 Castle Point Terrace
# 297                             700 First Street Room 1P
# 304                               Castle Point On Hudson
# 306                                    422 Willow Avenue
# 312                                     124 Grand Street
# 314                                713 Washington Street
# 316                                     124 Grand Street
# 321    1015 Washington Street Unit 50 C/O Paul Nesham...
# 329                                     121 River Street
# 332                                   50 Harrison Street
# 335                               1005 Washington Street
# 337                                    301 Garden Street
# 341                              1115 Willow Ave Ste 512
# 344                                  1408 Clinton Street
# 346                                 497 Observer Highway
# 347                             806 Castle Point Terrace
# 349                    Theta Xi Fraternity-Gamma Chapter
# 351                          36 Newark Street Rm/Ste 501
# 356                                     10 Church Towers
# 358                                     121 River Street
# 360                                 123 Jefferson Avenue
# 362                                   411 Clinton Street
# 364                                510 Washington Street
# Name: address_code, dtype: object

# %% [markdown]
# Let's delete all the irrelevant numbers (eg, unit number) from the end. I hard coded since we do not have that many endings, but future code with a larger data set can be improved. I used https://regex101.com/ to optimize the regular expressions.

# %%
df['address_code']=df['address_code'].apply(lambda address: 
                                       re.findall(r'(.*(?:Street|St|Ave|Avenue|Hudson|Highway|Terrace|Rd|Towers|Rm/St|Chapter|Inc))',address)[0])

df['address_code']
# Out:
# 11            Castle Point On The Hudson
# 14                    514 Madison Street
# 64                 713 Washington Street
# 96                     301 Garden Street
# 107               Party With Purpose Inc
# 110                       308 Willow Ave
# 111                      25 Fifth Street
# 155                    404 Hudson Street
# 177               601-603 Jackson Street
# 213                   1460 Garden Street
# 224                         601 Park Ave
# 232                        106 Hudson St
# 249                       308 Willow Ave
# 255           C/O P Capra 51 Harrison St
# 259        Hoboken Historical Museum Inc
# 265                    301 Garden Street
# 278                    301 Garden Street
# 293                          251 10Th St
# 294             926 Castle Point Terrace
# 297                     700 First Street
# 304               Castle Point On Hudson
# 306                       422 Willow Ave
# 312                     124 Grand Street
# 314                713 Washington Street
# 316                     124 Grand Street
# 321               1015 Washington Street
# 329                     121 River Street
# 332                   50 Harrison Street
# 335               1005 Washington Street
# 337                    301 Garden Street
# 341                   1115 Willow Ave St
# 344                  1408 Clinton Street
# 346                 497 Observer Highway
# 347             806 Castle Point Terrace
# 349    Theta Xi Fraternity-Gamma Chapter
# 351               36 Newark Street Rm/St
# 356                     10 Church Towers
# 358                     121 River Street
# 360                    123 Jefferson Ave
# 362                   411 Clinton Street
# 364                510 Washington Street
# Name: address_code, dtype: object

# %%
df['address_code']=df['address_code']+ ', Hoboken, Nj'
df['address_code']
# Out:
# 11            Castle Point On The Hudson, Hoboken, Nj
# 14                    514 Madison Street, Hoboken, Nj
# 64                 713 Washington Street, Hoboken, Nj
# 96                     301 Garden Street, Hoboken, Nj
# 107               Party With Purpose Inc, Hoboken, Nj
# 110                       308 Willow Ave, Hoboken, Nj
# 111                      25 Fifth Street, Hoboken, Nj
# 155                    404 Hudson Street, Hoboken, Nj
# 177               601-603 Jackson Street, Hoboken, Nj
# 213                   1460 Garden Street, Hoboken, Nj
# 224                         601 Park Ave, Hoboken, Nj
# 232                        106 Hudson St, Hoboken, Nj
# 249                       308 Willow Ave, Hoboken, Nj
# 255           C/O P Capra 51 Harrison St, Hoboken, Nj
# 259        Hoboken Historical Museum Inc, Hoboken, Nj
# 265                    301 Garden Street, Hoboken, Nj
# 278                    301 Garden Street, Hoboken, Nj
# 293                          251 10Th St, Hoboken, Nj
# 294             926 Castle Point Terrace, Hoboken, Nj
# 297                     700 First Street, Hoboken, Nj
# 304               Castle Point On Hudson, Hoboken, Nj
# 306                       422 Willow Ave, Hoboken, Nj
# 312                     124 Grand Street, Hoboken, Nj
# 314                713 Washington Street, Hoboken, Nj
# 316                     124 Grand Street, Hoboken, Nj
# 321               1015 Washington Street, Hoboken, Nj
# 329                     121 River Street, Hoboken, Nj
# 332                   50 Harrison Street, Hoboken, Nj
# 335               1005 Washington Street, Hoboken, Nj
# 337                    301 Garden Street, Hoboken, Nj
# 341                   1115 Willow Ave St, Hoboken, Nj
# 344                  1408 Clinton Street, Hoboken, Nj
# 346                 497 Observer Highway, Hoboken, Nj
# 347             806 Castle Point Terrace, Hoboken, Nj
# 349    Theta Xi Fraternity-Gamma Chapter, Hoboken, Nj
# 351               36 Newark Street Rm/St, Hoboken, Nj
# 356                     10 Church Towers, Hoboken, Nj
# 358                     121 River Street, Hoboken, Nj
# 360                    123 Jefferson Ave, Hoboken, Nj
# 362                   411 Clinton Street, Hoboken, Nj
# 364                510 Washington Street, Hoboken, Nj
# Name: address_code, dtype: object

# %% [markdown]
# Finally, geocoding the address....

# %%
df['location'] = df['address_code'].apply(geocode)
df['point'] = df['location'].apply(lambda loc: tuple(loc.point) if loc else None)
df['latitude']=df['point'].str[0]
df['longitude']=df['point'].str[1]
df_backup=df.copy()
df.head(5)
# Out:
#            ein                            name_org  tax_yr              phone  \
# 11   226052626          STEVENS ALUMNI ASSOCIATION    2011  +1 (201) 216-5163
# 14   222891851                  Columbian Arms Inc    2015               None
# 64   223517040          HOBOKEN CHARTER SCHOOL INC    2016  +1 (201) 963-0222
# 96   221801849  HOPES COMMUNITY ACTION PARTNERSHIP    2016  +1 (855) 654-6737
# 107  200596839              Party With Purpose Inc    2014  +1 (201) 988-7175
#
#                          website                     address formation_yr  \
# 11   WWW.ALUMNI.STEVENS-TECH.EDU  Castle Point On The Hudson         1958
# 14                          None          514 Madison Street         1987
# 64             WWW.HOBOKENCS.ORG       713 Washington Street         1997
# 96                 WWW.HOPES.ORG           301 Garden Street         1964
# 107                         None                 Po Box 1045         2002
#
#      gross_receipts ntee_code_nccs_x      ntee_description_nccs  ...  \
# 11           956073              B84        Alumni Associations  ...
# 14           896454              L21  Public Housing Facilities  ...
# 64          5346175             None                       None  ...
# 96         16748872              S20                       None  ...
# 107          183780              T31      Community Foundations  ...
#
#      volunteer_tot_ct  gross_receipts:1 rev_tot_curyr  rev_less_expense_curyr  \
# 11                300            956073        705616                  -22150
# 14               None            896454        -40166                  -40166
# 64               None           5346175       5346175                  276176
# 96                788          16748872      15513189                 1916145
# 107               100            183780        183780                   55830
#
#      local_chapt                             address_code  \
# 11            no  Castle Point On The Hudson, Hoboken, Nj
# 14            no          514 Madison Street, Hoboken, Nj
# 64            no       713 Washington Street, Hoboken, Nj
# 96            no           301 Garden Street, Hoboken, Nj
# 107           no      Party With Purpose Inc, Hoboken, Nj
#
#                                               location  \
# 11   (Castle Point on Hudson, Sinatra Drive, Hoboke...
# 14   (514, Madison Street, Hoboken, Hudson County, ...
# 64   (713, Washington Street, Hoboken, Hudson Count...
# 96   (301, Garden Street, Hoboken, Hudson County, N...
# 107                                               None
#
#                                             point   latitude  longitude
# 11         (40.74435205, -74.02378415629497, 0.0)  40.744352 -74.023784
# 14           (40.743918, -74.03775914285714, 0.0)  40.743918 -74.037759
# 64   (40.74615489090909, -74.02808611818182, 0.0)  40.746155 -74.028086
# 96                    (40.74038, -74.031745, 0.0)  40.740380 -74.031745
# 107                                          None        NaN        NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# Even though NTEE code is very detailed, shown by numbers after the alphabet, I am only interested the main divisions I coded the empty values as Z, which is consistent with the original NTEE code.

# %%
df['ntee_code_nccs_x']=df['ntee_code_nccs_x'].str[0]
df['ntee_code_nccs_x']=df['ntee_code_nccs_x'].apply(lambda code: 'Z' if pd.isna(code)==True else code)
uniq_code=list(set(df['ntee_code_nccs_x']))

# %% [markdown]
# # Plotting the Map
# To plot, I used folium as this was fairly easy to use, and you do not need any additional permission. You can see the representation of the map can be improved, which will be discussed later, but I think this is a great way to explore geospatial data.

# %%
# Included colors so each marker can be color-coded
colors=['darkred', 'blue', 'green', 'purple', 'orange','lightgray', 'gray',
        'darkblue', 'darkgreen', 'cadetblue', 'darkpurple', 'pink', 'lightblue','black']

def codecolors(counter):
    for i in range(0,len(colors)):
        if counter == uniq_code[i]:
            return colors[i]
    
df['color'] = df['ntee_code_nccs_x'].apply(codecolors)
df.head(5)
# Out:
#            ein                            name_org  tax_yr              phone  \
# 11   226052626          STEVENS ALUMNI ASSOCIATION    2011  +1 (201) 216-5163
# 14   222891851                  Columbian Arms Inc    2015               None
# 64   223517040          HOBOKEN CHARTER SCHOOL INC    2016  +1 (201) 963-0222
# 96   221801849  HOPES COMMUNITY ACTION PARTNERSHIP    2016  +1 (855) 654-6737
# 107  200596839              Party With Purpose Inc    2014  +1 (201) 988-7175
#
#                          website                     address formation_yr  \
# 11   WWW.ALUMNI.STEVENS-TECH.EDU  Castle Point On The Hudson         1958
# 14                          None          514 Madison Street         1987
# 64             WWW.HOBOKENCS.ORG       713 Washington Street         1997
# 96                 WWW.HOPES.ORG           301 Garden Street         1964
# 107                         None                 Po Box 1045         2002
#
#      gross_receipts ntee_code_nccs_x      ntee_description_nccs  ...  \
# 11           956073                B        Alumni Associations  ...
# 14           896454                L  Public Housing Facilities  ...
# 64          5346175                Z                       None  ...
# 96         16748872                S                       None  ...
# 107          183780                T      Community Foundations  ...
#
#      gross_receipts:1  rev_tot_curyr rev_less_expense_curyr  local_chapt  \
# 11             956073         705616                 -22150           no
# 14             896454         -40166                 -40166           no
# 64            5346175        5346175                 276176           no
# 96           16748872       15513189                1916145           no
# 107            183780         183780                  55830           no
#
#                                 address_code  \
# 11   Castle Point On The Hudson, Hoboken, Nj
# 14           514 Madison Street, Hoboken, Nj
# 64        713 Washington Street, Hoboken, Nj
# 96            301 Garden Street, Hoboken, Nj
# 107      Party With Purpose Inc, Hoboken, Nj
#
#                                               location  \
# 11   (Castle Point on Hudson, Sinatra Drive, Hoboke...
# 14   (514, Madison Street, Hoboken, Hudson County, ...
# 64   (713, Washington Street, Hoboken, Hudson Count...
# 96   (301, Garden Street, Hoboken, Hudson County, N...
# 107                                               None
#
#                                             point   latitude  longitude  \
# 11         (40.74435205, -74.02378415629497, 0.0)  40.744352 -74.023784
# 14           (40.743918, -74.03775914285714, 0.0)  40.743918 -74.037759
# 64   (40.74615489090909, -74.02808611818182, 0.0)  40.746155 -74.028086
# 96                    (40.74038, -74.031745, 0.0)  40.740380 -74.031745
# 107                                          None        NaN        NaN
#
#          color
# 11     darkred
# 14       green
# 64   lightgray
# 96        blue
# 107     orange
#
# [5 rows x 23 columns]

# %%
df
# Out:
#            ein                                           name_org  tax_yr  \
# 11   226052626                         STEVENS ALUMNI ASSOCIATION    2011
# 14   222891851                                 Columbian Arms Inc    2015
# 64   223517040                         HOBOKEN CHARTER SCHOOL INC    2016
# 96   221801849                 HOPES COMMUNITY ACTION PARTNERSHIP    2016
# 107  200596839                             Party With Purpose Inc    2014
# 110   10873064                              HUDSON HEALTHCARE INC    2010
# 111  300060431  LITTLE LEAGUE BASEBALL INC 2300706 HOBOKEN LIT...    2011
# 155  462360340                         THE WATERFRONT PROJECT INC    2015
# 177  912073437  ALL SAINTS COMMUNITY SERVICE AND DEVELOPMENT C...    2014
# 213  223536228   FRIENDS OF THE ELYSIAN CHARTER SCHOOL OF HOBOKEN    2015
# 224  222221017                                  THE HUDSON SCHOOL    2014
# 232  237450006                               HOBOKEN PBA LOCAL #2    2017
# 249  452486602                   HOBOKEN COMMUNITY HEALTHCARE INC    2011
# 255  262291191                  THE ANTHONY FASANO FOUNDATION INC    2016
# 259  222700679                      HOBOKEN HISTORICAL MUSEUM INC    2016
# 265  222221257                  MILE SQUARE EARLY LEARNING CENTER    2016
# 278  222209099                         STEVENS COOPERATIVE SCHOOL    2012
# 293  453683776                     Global Team Players Foundation    2014
# 294  364703914               Kappa Sigma Fraternity 363 Rho Omega    2014
# 297  261530522                  Rene Abreu Christian Ministry Inc    2013
# 304  221487354                    STEVENS INSTITUTE OF TECHNOLOGY    2012
# 306  222267469                                MUSTARD SEED SCHOOL    2017
# 312  221986978                       HOBOKEN DAY CARE 100 PROGRAM    2015
# 314  223519265              FRIENDS OF HOBOKEN CHARTER SCHOOL INC    2015
# 316  222051458                        HOBOKEN FAMILY PLANNING INC    2011
# 321  136271999  ASSOCIATION OF THE GRADUATES OF THE COLUMBIA C...    2012
# 329  136842498  Marsh & McLennan Companies ER Funded Welfare B...    2015
# 332  202810783                  TRANSPORT WORKERS UNION LOCAL 229    2016
# 335  220764205   Benevolent & Protective Order of Elks of the USA    2017
# 337  223510684                             ELYSIAN CHARTER SCHOOL    2013
# 341  472837622    MAGIC ALWAYS HAPPENS A NJ NONPROFIT CORPORATION    2015
# 344   10778023                            MILE SQUARE THEATRE INC    2015
# 346  452594112  MAXWELL PLACE WATERFRONT PARK CORPORATION INC ...    2015
# 347  223395645                    Sigma Nu Fraternity Gamma Delta    2013
# 349  221657903                  THETA XI FRATERNITY-GAMMA CHAPTER    2011
# 351  452401943                                   CHOICE MEDIA INC    2017
# 356  221763570  CHURCH TOWERS URBAN RENEWAL CORP C/O TOTAL PRO...    2016
# 358  133202585  Marsh & McLennan Companies EE Funded Welfare B...    2011
# 360  271261831               HOBOKEN DUAL LANGUAGE CHARTER SCHOOL    2014
# 362  222831271                                   GOOD COUNSEL INC    2016
# 364  203671056                       Symposia Community Bookstore    2012
#
#                  phone                             website  \
# 11   +1 (201) 216-5163         WWW.ALUMNI.STEVENS-TECH.EDU
# 14                None                                None
# 64   +1 (201) 963-0222                   WWW.HOBOKENCS.ORG
# 96   +1 (855) 654-6737                       WWW.HOPES.ORG
# 107  +1 (201) 988-7175                                None
# 110  +1 (201) 418-2249                  WWW.HOBOKENUMC.COM
# 111  +1 (201) 697-1995                    LEAGUELINEUP.COM
# 155  +1 (201) 308-3986        WWW.THEWATERFRONTPROJECT.ORG
# 177  +1 (201) 792-0340                          ASCSDC.ORG
# 213  +1 (201) 876-0102                                None
# 224  +1 (201) 659-8335                                None
# 232  +1 (201) 420-2100                      hobokenpba.com
# 249  +1 (201) 418-2055                                None
# 255  +1 (973) 228-5500                                None
# 259  +1 (201) 656-2240               WWW.HOBOKENMUSEUM.ORG
# 265  +1 (201) 659-6086                   WWW.MSELC1979.ORG
# 278  +1 (201) 792-3688                 www.stevenscoop.org
# 293  +1 (917) 723-1985                 www.teamplayers.org
# 294  +1 (718) 689-4608  http://web.stevens.edu/kappasigma/
# 297  +1 (201) 656-5100                                None
# 304  +1 (201) 216-8761                     WWW.STEVENS.EDU
# 306  +1 (201) 653-5548           WWW.MUSTARDSEEDSCHOOL.ORG
# 312  +1 (201) 792-4666                                None
# 314  +1 (201) 963-0222                      WWW.HCS-PA.ORG
# 316  +1 (201) 963-0300                  WWW.HOBFAMPLAN.NET
# 321  +1 (201) 993-9480                                None
# 329  +1 (201) 284-4115                                None
# 332  +1 (201) 792-4450                                None
# 335  +1 (201) 656-9602                                None
# 337  +1 (201) 876-0102                    HTTP://ECSNJ.ORG
# 341  +1 (212) 498-9877              MAGICALWAYSHAPPENS.ORG
# 344  +1 (201) 683-7014            WWW.MILESQUARETHEARE.ORG
# 346  +1 (201) 656-8323                                None
# 347               None            www.stevens.edu/sigma_nu
# 349  +1 (201) 916-3787                                None
# 351  +1 (201) 239-1270              HTTP://CHOICEMEDIA.TV/
# 356  +1 (201) 659-0604                                None
# 358  +1 (201) 284-4115                                None
# 360  +1 (201) 427-1458                     HOLAHOBOKEN.ORG
# 362  +1 (201) 795-0637                GOODCOUNSELHOMES.ORG
# 364  +1 (201) 963-0909                                None
#
#                                                address formation_yr  \
# 11                          Castle Point On The Hudson         1958
# 14                                  514 Madison Street         1987
# 64                               713 Washington Street         1997
# 96                                   301 Garden Street         1964
# 107                                        Po Box 1045         2002
# 110                                     308 Willow Ave         2007
# 111                     25 Fifth Street The Fieldhouse         1990
# 155                                  404 Hudson Street         2013
# 177                             601-603 Jackson Street         1995
# 213                                 1460 Garden Street         1998
# 224                                    601 Park Avenue         1978
# 232                            106 Hudson St 2Nd Floor         1992
# 249                                  308 Willow Avenue         2011
# 255                   C/O P Capra 51 Harrison St No 5D         2008
# 259                                        Po Box 3296         1986
# 265                                  301 Garden Street         1978
# 278                                  301 Garden Street         1949
# 293                                      251 10Th St B         2010
# 294                           926 Castle Point Terrace         2012
# 297                           700 First Street Room 1P         2007
# 304                             Castle Point On Hudson         1870
# 306                                  422 Willow Avenue         1979
# 312                                   124 Grand Street         1972
# 314                              713 Washington Street         1997
# 316                                   124 Grand Street         1972
# 321  1015 Washington Street Unit 50 C/O Paul Nesham...         None
# 329                                   121 River Street         1982
# 332                                 50 Harrison Street         2008
# 335                             1005 Washington Street         1905
# 337                                  301 Garden Street         1996
# 341                            1115 Willow Ave Ste 512         None
# 344                                1408 Clinton Street         2003
# 346                               497 Observer Highway         2011
# 347                           806 Castle Point Terrace         1940
# 349                                         Po Box 865         1874
# 351                        36 Newark Street Rm/Ste 501         2011
# 356                                   10 Church Towers         1965
# 358                                   121 River Street         1986
# 360                               123 Jefferson Avenue         2009
# 362                                 411 Clinton Street         1985
# 364                              510 Washington Street         2007
#
#      gross_receipts ntee_code_nccs_x  \
# 11           956073                B
# 14           896454                L
# 64          5346175                Z
# 96         16748872                S
# 107          183780                T
# 110       130061664                E
# 111           22030                N
# 155           90696                R
# 177         1034016                S
# 213          437918                B
# 224         3321312                B
# 232          221604                Z
# 249          721922                E
# 255           12520                Z
# 259          426009                A
# 265         5377065                P
# 278         7228390                B
# 293            9260                A
# 294               0                B
# 297          359455                X
# 304       300534329                B
# 306         6802907                B
# 312          602503                P
# 314          590741                B
# 316         2347563                E
# 321          227400                B
# 329       222549140                Y
# 332           80316                J
# 335          219307                Y
# 337         4840744                B
# 341           12740                G
# 344          446888                A
# 346          392083                N
# 347          498753                B
# 349          109337                B
# 351          345473                A
# 356         4451678                S
# 358         8817509                Y
# 360         3358728                B
# 362         6299894                P
# 364          230091                P
#
#                                  ntee_description_nccs  ...  gross_receipts:1  \
# 11                                 Alumni Associations  ...            956073
# 14                           Public Housing Facilities  ...            896454
# 64                                                None  ...           5346175
# 96                                                None  ...          16748872
# 107                              Community Foundations  ...            183780
# 110  Public Health Program (Includes General Health...  ...         130061664
# 111                                 Baseball, Softball  ...             22030
# 155                                    Minority Rights  ...             90696
# 177  Community, Neighborhood Development, Improveme...  ...           1034016
# 213                                          Education  ...            437918
# 224                 Specialized Education Institutions  ...           3321312
# 232                                               None  ...            221604
# 249         Ambulatory Health Center, Community Clinic  ...            721922
# 255                                               None  ...             12520
# 259                                               None  ...            426009
# 265                                     Child Day Care  ...           5377065
# 278                        Primary, Elementary Schools  ...           7228390
# 293                                            Theater  ...              9260
# 294                   Student Sororities, Fraternities  ...                 0
# 297                                          Christian  ...            359455
# 304              University or Technological Institute  ...         300534329
# 306                                               None  ...           6802907
# 312                                     Child Day Care  ...            602503
# 314                                          Education  ...            590741
# 316                            Family Planning Centers  ...           2347563
# 321                   Student Sororities, Fraternities  ...            227400
# 329  Voluntary Employees Beneficiary Associations (...  ...         222549140
# 332                                               None  ...             80316
# 335                                               None  ...            219307
# 337                                          Education  ...           4840744
# 341                 Birth Defects and Genetic Diseases  ...             12740
# 344                                            Theater  ...            446888
# 346                              Parks and Playgrounds  ...            392083
# 347                   Student Sororities, Fraternities  ...            498753
# 349                   Student Sororities, Fraternities  ...            109337
# 351                                               None  ...            345473
# 356                                               None  ...           4451678
# 358  Voluntary Employees Beneficiary Associations (...  ...           8817509
# 360                                          Education  ...           3358728
# 362                                               None  ...           6299894
# 364                                       Thrift Shops  ...            230091
#
#      rev_tot_curyr rev_less_expense_curyr  local_chapt  \
# 11          705616                 -22150           no
# 14          -40166                 -40166           no
# 64         5346175                 276176           no
# 96        15513189                1916145           no
# 107         183780                  55830           no
# 110      130025839              -23106291           no
# 111          22030                  -2184           no
# 155          90696                  10449           no
# 177        1013372                -260140           no
# 213         347354                -154668           no
# 224        3296695                 351670           no
# 232         221604                  71919           no
# 249         721922                      0           no
# 255           8003                   -979           no
# 259         400413                  10576           no
# 265        5377065                 168136           no
# 278        7145550                 311828           no
# 293           9260                   -683           no
# 294              0                      0           no
# 297         359455                 206870          yes
# 304      226416710                5211293           no
# 306        6802907                 810504           no
# 312         602503                  24905           no
# 314         150349                 -31288           no
# 316        2335946                  -5195           no
# 321         227400                   1057           no
# 329      222549140               -9402278           no
# 332          80316                   2824           no
# 335         157233                  12408           no
# 337        4840744                 116560           no
# 341          12740                  -3688           no
# 344         446888                 103181           no
# 346         392083                 225825           no
# 347         213613                  26326           no
# 349         109337                   3341           no
# 351         345473                 -28322           no
# 356        4451678                  95074           no
# 358        8817509                -874523           no
# 360        3358728                 168746           no
# 362        6157961                1145944          yes
# 364         230091                  -1675           no
#
#                                        address_code  \
# 11          Castle Point On The Hudson, Hoboken, Nj
# 14                  514 Madison Street, Hoboken, Nj
# 64               713 Washington Street, Hoboken, Nj
# 96                   301 Garden Street, Hoboken, Nj
# 107             Party With Purpose Inc, Hoboken, Nj
# 110                     308 Willow Ave, Hoboken, Nj
# 111                    25 Fifth Street, Hoboken, Nj
# 155                  404 Hudson Street, Hoboken, Nj
# 177             601-603 Jackson Street, Hoboken, Nj
# 213                 1460 Garden Street, Hoboken, Nj
# 224                       601 Park Ave, Hoboken, Nj
# 232                      106 Hudson St, Hoboken, Nj
# 249                     308 Willow Ave, Hoboken, Nj
# 255         C/O P Capra 51 Harrison St, Hoboken, Nj
# 259      Hoboken Historical Museum Inc, Hoboken, Nj
# 265                  301 Garden Street, Hoboken, Nj
# 278                  301 Garden Street, Hoboken, Nj
# 293                        251 10Th St, Hoboken, Nj
# 294           926 Castle Point Terrace, Hoboken, Nj
# 297                   700 First Street, Hoboken, Nj
# 304             Castle Point On Hudson, Hoboken, Nj
# 306                     422 Willow Ave, Hoboken, Nj
# 312                   124 Grand Street, Hoboken, Nj
# 314              713 Washington Street, Hoboken, Nj
# 316                   124 Grand Street, Hoboken, Nj
# 321             1015 Washington Street, Hoboken, Nj
# 329                   121 River Street, Hoboken, Nj
# 332                 50 Harrison Street, Hoboken, Nj
# 335             1005 Washington Street, Hoboken, Nj
# 337                  301 Garden Street, Hoboken, Nj
# 341                 1115 Willow Ave St, Hoboken, Nj
# 344                1408 Clinton Street, Hoboken, Nj
# 346               497 Observer Highway, Hoboken, Nj
# 347           806 Castle Point Terrace, Hoboken, Nj
# 349  Theta Xi Fraternity-Gamma Chapter, Hoboken, Nj
# 351             36 Newark Street Rm/St, Hoboken, Nj
# 356                   10 Church Towers, Hoboken, Nj
# 358                   121 River Street, Hoboken, Nj
# 360                  123 Jefferson Ave, Hoboken, Nj
# 362                 411 Clinton Street, Hoboken, Nj
# 364              510 Washington Street, Hoboken, Nj
#
#                                               location  \
# 11   (Castle Point on Hudson, Sinatra Drive, Hoboke...
# 14   (514, Madison Street, Hoboken, Hudson County, ...
# 64   (713, Washington Street, Hoboken, Hudson Count...
# 96   (301, Garden Street, Hoboken, Hudson County, N...
# 107                                               None
# 110  (Hoboken University Medical Center, 308, Willo...
# 111                                               None
# 155  (Saints Peter and Paul RC Church, 404, Hudson ...
# 177  (Jubilee Center, 601-603, Jackson Street, Hobo...
# 213  (1460, Garden Street, Hoboken, Hudson County, ...
# 224  (601, Park Avenue, Hoboken, Hudson County, New...
# 232  (Hoboken Police Station, 106, Hudson Street, H...
# 249  (Hoboken University Medical Center, 308, Willo...
# 255                                               None
# 259                                               None
# 265  (301, Garden Street, Hoboken, Hudson County, N...
# 278  (301, Garden Street, Hoboken, Hudson County, N...
# 293  (251, 10th Street, Hoboken, Hudson County, New...
# 294  (Kappa Sigma Fraternity, 926, Castle Point Ter...
# 297                                               None
# 304  (Castle Point on Hudson, Sinatra Drive, Hoboke...
# 306  (422, Willow Avenue, Hoboken, Hudson County, N...
# 312  (124, Grand Street, Hoboken, Hudson County, Ne...
# 314  (713, Washington Street, Hoboken, Hudson Count...
# 316  (124, Grand Street, Hoboken, Hudson County, Ne...
# 321  (1015, Washington Street, Hoboken, Hudson Coun...
# 329  (FedEx, 121, River Street, Hoboken, Hudson Cou...
# 332  (Hoboken Small Business Center, 50, Harrison S...
# 335  (Elks Lodge, 1005, Washington Street, Hoboken,...
# 337  (301, Garden Street, Hoboken, Hudson County, N...
# 341  (1115, Willow Avenue, Hoboken, Hudson County, ...
# 344  (1408, Clinton Street, Hoboken, Hudson County,...
# 346  (497, Observer Highway, Hoboken, Hudson County...
# 347  (Sigma Nu Fraternity, 806, Castle Point Terrac...
# 349                                               None
# 351                                               None
# 356  (10 Church Towers, Clinton Street, Hoboken, Hu...
# 358  (FedEx, 121, River Street, Hoboken, Hudson Cou...
# 360                                               None
# 362  (411, Clinton Street, Hoboken, Hudson County, ...
# 364  (Symposia Bookstore, 510, Washington Street, H...
#
#                                              point   latitude  longitude  \
# 11          (40.74435205, -74.02378415629497, 0.0)  40.744352 -74.023784
# 14            (40.743918, -74.03775914285714, 0.0)  40.743918 -74.037759
# 64    (40.74615489090909, -74.02808611818182, 0.0)  40.746155 -74.028086
# 96                     (40.74038, -74.031745, 0.0)  40.740380 -74.031745
# 107                                           None        NaN        NaN
# 110  (40.741482500000004, -74.03397040924716, 0.0)  40.741483 -74.033970
# 111                                           None        NaN        NaN
# 155         (40.74128815, -74.02891129487821, 0.0)  40.741288 -74.028911
# 177         (40.74537425, -74.03886447905842, 0.0)  40.745374 -74.038864
# 213   (40.75398251482986, -74.02781848704882, 0.0)  40.753983 -74.027818
# 224                 (40.7440209, -74.0316067, 0.0)  40.744021 -74.031607
# 232         (40.73771585, -74.03001137596758, 0.0)  40.737716 -74.030011
# 249  (40.741482500000004, -74.03397040924716, 0.0)  40.741483 -74.033970
# 255                                           None        NaN        NaN
# 259                                           None        NaN        NaN
# 265                    (40.74038, -74.031745, 0.0)  40.740380 -74.031745
# 278                    (40.74038, -74.031745, 0.0)  40.740380 -74.031745
# 293                   (40.748994, -74.030387, 0.0)  40.748994 -74.030387
# 294          (40.7481037, -74.02570405676256, 0.0)  40.748104 -74.025704
# 297                                           None        NaN        NaN
# 304         (40.74435205, -74.02378415629497, 0.0)  40.744352 -74.023784
# 306   (40.74216387999555, -74.03338349333463, 0.0)  40.742164 -74.033383
# 312   (40.73878973469388, -74.03637734693878, 0.0)  40.738790 -74.036377
# 314   (40.74615489090909, -74.02808611818182, 0.0)  40.746155 -74.028086
# 316   (40.73878973469388, -74.03637734693878, 0.0)  40.738790 -74.036377
# 321         (40.74899755, -74.02702575509001, 0.0)  40.748998 -74.027026
# 329                 (40.7379324, -74.0284078, 0.0)  40.737932 -74.028408
# 332         (40.73739665, -74.04307101935605, 0.0)  40.737397 -74.043071
# 335                 (40.7488534, -74.0272148, 0.0)  40.748853 -74.027215
# 337                    (40.74038, -74.031745, 0.0)  40.740380 -74.031745
# 341     (40.751064568749996, -74.03042049375, 0.0)  40.751065 -74.030420
# 344   (40.75428985714286, -74.03062589795918, 0.0)  40.754290 -74.030626
# 346   (40.736719111111114, -74.0384163939394, 0.0)  40.736719 -74.038416
# 347         (40.74631985, -74.02624756310624, 0.0)  40.746320 -74.026248
# 349                                           None        NaN        NaN
# 351                                           None        NaN        NaN
# 356  (40.742594249999996, -74.03442075329194, 0.0)  40.742594 -74.034421
# 358                 (40.7379324, -74.0284078, 0.0)  40.737932 -74.028408
# 360                                           None        NaN        NaN
# 362   (40.74220016326531, -74.03411906122449, 0.0)  40.742200 -74.034119
# 364                 (40.7426339, -74.0295268, 0.0)  40.742634 -74.029527
#
#           color
# 11      darkred
# 14        green
# 64    lightgray
# 96         blue
# 107      orange
# 110   darkgreen
# 111        pink
# 155   cadetblue
# 177        blue
# 213     darkred
# 224     darkred
# 232   lightgray
# 249   darkgreen
# 255   lightgray
# 259       black
# 265    darkblue
# 278     darkred
# 293       black
# 294     darkred
# 297  darkpurple
# 304     darkred
# 306     darkred
# 312    darkblue
# 314     darkred
# 316   darkgreen
# 321     darkred
# 329   lightblue
# 332      purple
# 335   lightblue
# 337     darkred
# 341        gray
# 344       black
# 346        pink
# 347     darkred
# 349     darkred
# 351       black
# 356        blue
# 358   lightblue
# 360     darkred
# 362    darkblue
# 364    darkblue
#
# [41 rows x 23 columns]

# %% [markdown]
# Some of the addresses were not coded because the original addresses are a little strange. For example, searching Party with Purpose Inc on the Internet shows that they throws events at different places, and they may not have a physical office. Thus, the longitude and latitude of these places will be filled with the position of the center of the city.

# %%
import folium

df['longitude']=df['longitude'].fillna(-74.032694)
df['latitude']=df['latitude'].fillna(40.744070)
m = folium.Map(location=[40.744070, -74.032694],tiles='CartoDB positron', zoom_start=15)

# %% [markdown]
# To create a legend, I have copied down what each alphabet represents and created a label in the data frame.

# %%
ntee_label=['Education', 'Philanthropy, Voluntarism & Grantmaking Foundations', 'Arts, Culture & Humanities',
            'Employment','Health Care','Civil Rights, Social Action & Advocacy',
            'Voluntary Health Associations & Medical Disciplines',
            'Unknown/Not Specified', 'Housing & Shelter',
            'Community Improvement & Capacity Building','Human Services',
            'Religion-Related','Mutual & Membership Benefit','Recreation & Sports'
            ]
def labelcode(counter):
    for i in range(0,len(ntee_label)):
        if counter == uniq_code[i]:
            return ntee_label[i]
df['ntee_label'] = df['ntee_code_nccs_x'].apply(labelcode)  
df['name_org']=df['name_org'].str.title() 

# Filling in empty values...
df['address']=df['address'].str[:-13]
df['phone']=df['phone'].apply(lambda x: 'N/A' if pd.isna(x)==True else x)

# %% [markdown]
# To label the markers, I have added the name of the organization, address, and phone number. The original folium does not have an easy way to implement legend on the map, so I used html to created a legend. Because of this, the colors are a little off. The general folium plotting was inspired by the sites below:
# - https://georgetsilva.github.io/posts/mapping-points-with-folium/
# - https://geopy.readthedocs.io/en/stable/#module-geopy.geocoders
# - https://python-visualization.github.io/folium/modules.html

# %%
from folium.plugins import MarkerCluster

marker_cluster = MarkerCluster().add_to(m)
df.apply(lambda row:folium.Marker(
    location=[row['latitude'], row['longitude']], 
    popup=row['name_org']+'  '+row['address'] +'  '+row['phone'], max_width=500,min_width=400,
    icon=folium.Icon(color=row['color'], icon='hand-holding-heart')).add_to(marker_cluster),
         axis=1)

legend_html =   '''
                <div style="position: fixed; 
                            bottom: 40px; left: 40px; width: 410px; height:380px; 
                            border:2px solid grey; z-index:9999; font-size:12px;
                            ">&nbsp; Ntee code <br>
                              &nbsp; Education &nbsp; <i class="fa fa-map-marker fa-2x" style="color:darkred"></i><br>
                              &nbsp; Philan., Volunt. & Grantmaking Foundations &nbsp; <i class="fa fa-map-marker fa-2x" style="color:dodgerblue"></i><br>
                              &nbsp; Arts, Culture & Humanities &nbsp; <i class="fa fa-map-marker fa-2x" style="color:forestgreen"></i><br>
                              &nbsp; Employment &nbsp; <i class="fa fa-map-marker fa-2x" style="color:mediumorchid"></i><br>
                              &nbsp; Health Care &nbsp; <i class="fa fa-map-marker fa-2x" style="color:orange"></i><br>
                              &nbsp; Civil Rights, Social Action & Adv. &nbsp; <i class="fa fa-map-marker fa-2x" style="color:gray"></i><br>
                              &nbsp; Volunt. Health Asso. & Medical Discipl. &nbsp; <i class="fa fa-map-marker fa-2x" style="color:dimgray"></i><br>
                              &nbsp; Unknown/Not Specified &nbsp; <i class="fa fa-map-marker fa-2x" style="color:steelblue"></i><br>
                              &nbsp; Housing & Shelter &nbsp; <i class="fa fa-map-marker fa-2x" style="color:darkolivegreen"></i><br>
                              &nbsp; Community Improv. & Capacity Building &nbsp; <i class="fa fa-map-marker fa-2x" style="color:darkcyan"></i><br>
                              &nbsp; Human Services &nbsp; <i class="fa fa-map-marker fa-2x" style="color:indigo"></i><br>
                              &nbsp; Religion-Related &nbsp; <i class="fa fa-map-marker fa-2x" style="color:magenta"></i><br>
                              &nbsp; Mutual & Member. Benefit &nbsp; <i class="fa fa-map-marker fa-2x" style="color:lightskyblue"></i><br>
                              &nbsp; Recreation & Sports &nbsp; <i class="fa fa-map-marker fa-2x" style="color:black"></i>
                </div>
                ''' 

m.get_root().html.add_child(folium.Element(legend_html))

m.save('hoboken_map.html')

# %% [markdown]
# We still see 8 addresses that are not properly coded. This is because some of the addresses that are listed in words (eg, Fifth street) are not properly coded. We will code them using a dictionary.

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# You can see that it has now been coded properly.

# %%
text_dict = {'First':'1st', 'Second':'2nd', 'Third':'3rd', 'Fourth':'4th', 'Fifth':'5th', 'Sixth': '6th', 'Seventh':'7th', 'Eighth':'8th', 'Ninth':'9th'}
for word, initial in text_dict.items():
    df['address_code'] = df['address_code'].apply(lambda x: x.replace(word, initial))
df['address_code']
# Out:
# 11            Castle Point On The Hudson, Hoboken, Nj
# 14                    514 Madison Street, Hoboken, Nj
# 64                 713 Washington Street, Hoboken, Nj
# 96                     301 Garden Street, Hoboken, Nj
# 107               Party With Purpose Inc, Hoboken, Nj
# 110                       308 Willow Ave, Hoboken, Nj
# 111                        25 5th Street, Hoboken, Nj
# 155                    404 Hudson Street, Hoboken, Nj
# 177               601-603 Jackson Street, Hoboken, Nj
# 213                   1460 Garden Street, Hoboken, Nj
# 224                         601 Park Ave, Hoboken, Nj
# 232                        106 Hudson St, Hoboken, Nj
# 249                       308 Willow Ave, Hoboken, Nj
# 255           C/O P Capra 51 Harrison St, Hoboken, Nj
# 259        Hoboken Historical Museum Inc, Hoboken, Nj
# 265                    301 Garden Street, Hoboken, Nj
# 278                    301 Garden Street, Hoboken, Nj
# 293                          251 10Th St, Hoboken, Nj
# 294             926 Castle Point Terrace, Hoboken, Nj
# 297                       700 1st Street, Hoboken, Nj
# 304               Castle Point On Hudson, Hoboken, Nj
# 306                       422 Willow Ave, Hoboken, Nj
# 312                     124 Grand Street, Hoboken, Nj
# 314                713 Washington Street, Hoboken, Nj
# 316                     124 Grand Street, Hoboken, Nj
# 321               1015 Washington Street, Hoboken, Nj
# 329                     121 River Street, Hoboken, Nj
# 332                   50 Harrison Street, Hoboken, Nj
# 335               1005 Washington Street, Hoboken, Nj
# 337                    301 Garden Street, Hoboken, Nj
# 341                   1115 Willow Ave St, Hoboken, Nj
# 344                  1408 Clinton Street, Hoboken, Nj
# 346                 497 Observer Highway, Hoboken, Nj
# 347             806 Castle Point Terrace, Hoboken, Nj
# 349    Theta Xi Fraternity-Gamma Chapter, Hoboken, Nj
# 351               36 Newark Street Rm/St, Hoboken, Nj
# 356                     10 Church Towers, Hoboken, Nj
# 358                     121 River Street, Hoboken, Nj
# 360                    123 Jefferson Ave, Hoboken, Nj
# 362                   411 Clinton Street, Hoboken, Nj
# 364                510 Washington Street, Hoboken, Nj
# Name: address_code, dtype: object

# %% [markdown]
# Now we are geocoding the address code again to see if we can plot most of the addresses appropriately. The legend is optimized for html, so we can ignore for now.

# %%
df['location'] = df['address_code'].apply(geocode)
df['point'] = df['location'].apply(lambda loc: tuple(loc.point) if loc else None)
df['latitude']=df['point'].str[0]
df['longitude']=df['point'].str[1]
df['longitude']=df['longitude'].fillna(-74.032694)
df['latitude']=df['latitude'].fillna(40.744070)

marker_cluster = MarkerCluster().add_to(m)
df.apply(lambda row:folium.Marker(
    location=[row['latitude'], row['longitude']], 
    popup=row['name_org']+'  '+row['address'] +'  '+row['phone'], max_width=500,min_width=400,
    icon=folium.Icon(color=row['color'], icon='human')).add_to(marker_cluster),
         axis=1)
legend_html =   '''
                <div style="position: fixed; 
                            bottom: 40px; left: 40px; width: 410px; height:380px; 
                            border:2px solid grey; z-index:9999; font-size:12px;
                            ">&nbsp; Ntee code <br>
                              &nbsp; Education &nbsp; <i class="fa fa-map-marker fa-2x" style="color:darkred"></i><br>
                              &nbsp; Philan., Volunt. & Grantmaking Foundations &nbsp; <i class="fa fa-map-marker fa-2x" style="color:dodgerblue"></i><br>
                              &nbsp; Arts, Culture & Humanities &nbsp; <i class="fa fa-map-marker fa-2x" style="color:forestgreen"></i><br>
                              &nbsp; Employment &nbsp; <i class="fa fa-map-marker fa-2x" style="color:mediumorchid"></i><br>
                              &nbsp; Health Care &nbsp; <i class="fa fa-map-marker fa-2x" style="color:orange"></i><br>
                              &nbsp; Civil Rights, Social Action & Adv. &nbsp; <i class="fa fa-map-marker fa-2x" style="color:gray"></i><br>
                              &nbsp; Volunt. Health Asso. & Medical Discipl. &nbsp; <i class="fa fa-map-marker fa-2x" style="color:dimgray"></i><br>
                              &nbsp; Unknown/Not Specified &nbsp; <i class="fa fa-map-marker fa-2x" style="color:steelblue"></i><br>
                              &nbsp; Housing & Shelter &nbsp; <i class="fa fa-map-marker fa-2x" style="color:darkolivegreen"></i><br>
                              &nbsp; Community Improv. & Capacity Building &nbsp; <i class="fa fa-map-marker fa-2x" style="color:darkcyan"></i><br>
                              &nbsp; Human Services &nbsp; <i class="fa fa-map-marker fa-2x" style="color:indigo"></i><br>
                              &nbsp; Religion-Related &nbsp; <i class="fa fa-map-marker fa-2x" style="color:magenta"></i><br>
                              &nbsp; Mutual & Member. Benefit &nbsp; <i class="fa fa-map-marker fa-2x" style="color:lightskyblue"></i><br>
                              &nbsp; Recreation & Sports &nbsp; <i class="fa fa-map-marker fa-2x" style="color:black"></i>
                </div>
                ''' 

m.get_root().html.add_child(folium.Element(legend_html))

m.save('hoboken_map.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Future improvements
# 1. As we can see, some of the NTEE codes are not relevant for our uses. Thus, we can bin them or delete some categories, which will help with the colors and legend size.
# 2. Address and phone number boxes are too small; based on the forum, I should be able to fix the width. However, it doesn't seem to be the case. This can be revisited next time.

# %%
pip install git+https://github.com/python-visualization/folium@master
# Out:
# Collecting git+https://github.com/python-visualization/folium@master
#   Cloning https://github.com/python-visualization/folium (to revision master) to c:\users\andrea\appdata\local\temp\pip-req-build-gbxd017v
# Requirement already satisfied (use --upgrade to upgrade): folium==0.10.1+8.g4affacb from git+https://github.com/python-visualization/folium@master in d:\anaconda\envs\ios\lib\site-packages
# Requirement already satisfied: branca>=0.3.0 in d:\anaconda\envs\ios\lib\site-packages (from folium==0.10.1+8.g4affacb) (0.4.0)
# Requirement already satisfied: jinja2>=2.9 in d:\anaconda\envs\ios\lib\site-packages (from folium==0.10.1+8.g4affacb) (2.10.3)
# Requirement already satisfied: numpy in d:\anaconda\envs\ios\lib\site-packages (from folium==0.10.1+8.g4affacb) (1.16.5)
# Requirement already satisfied: requests in d:\anaconda\envs\ios\lib\site-packages (from folium==0.10.1+8.g4affacb) (2.22.0)
# Requirement already satisfied: six in d:\anaconda\envs\ios\lib\site-packages (from branca>=0.3.0->folium==0.10.1+8.g4affacb) (1.12.0)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\anaconda\envs\ios\lib\site-packages (from jinja2>=2.9->folium==0.10.1+8.g4affacb) (1.1.1)
# Requirement already satisfied: idna<2.9,>=2.5 in d:\anaconda\envs\ios\lib\site-packages (from requests->folium==0.10.1+8.g4affacb) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in d:\anaconda\envs\ios\lib\site-packages (from requests->folium==0.10.1+8.g4affacb) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in d:\anaconda\envs\ios\lib\site-packages (from requests->folium==0.10.1+8.g4affacb) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\envs\ios\lib\site-packages (from requests->folium==0.10.1+8.g4affacb) (2019.11.28)
# Building wheels for collected packages: folium
#   Building wheel for folium (setup.py): started
#   Building wheel for folium (setup.py): finished with status 'done'
#   Created wheel for folium: filename=folium-0.10.1+8.g4affacb-py2.py3-none-any.whl size=94503 sha256=27ab6731e7d5c486d38e788f1fdd433ab8fa367c73541405f85de771d4b5402d
#   Stored in directory: C:\Users\Andrea\AppData\Local\Temp\pip-ephem-wheel-cache-86vb6m86\wheels\68\e4\23\2a744cccbfacdb83fbbe1025baa03503bba83167a7c4d12993
# Successfully built folium
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone -q https://github.com/python-visualization/folium 'C:\Users\Andrea\AppData\Local\Temp\pip-req-build-gbxd017v'

# %%
df['address_code']=df['address_code'].str[:-13]
m = folium.Map(location=[40.744070, -74.032694],tiles='CartoDB positron', zoom_start=15)
marker_cluster = MarkerCluster().add_to(m)
df.apply(lambda row:folium.Marker(
    location=[row['latitude'], row['longitude']], 
    popup=row['name_org']+'  '+row['address_code'] +'  '+row['phone'], max_width=1000,min_width=900,
    icon=folium.Icon(color=row['color'], icon='hand-holding-heart')).add_to(marker_cluster),
         axis=1)
legend_html =   '''
                <div style="position: fixed; 
                            bottom: 40px; left: 40px; width: 370px; height:380px; 
                            border:2px solid grey; z-index:9999; font-size:12px;
                            ">&nbsp; Ntee code <br>
                              &nbsp; Education &nbsp; <i class="fa fa-map-marker fa-2x" style="color:darkred"></i><br>
                              &nbsp; Philan., Volunt. & Grantmaking Foundations &nbsp; <i class="fa fa-map-marker fa-2x" style="color:dodgerblue"></i><br>
                              &nbsp; Arts, Culture & Humanities &nbsp; <i class="fa fa-map-marker fa-2x" style="color:forestgreen"></i><br>
                              &nbsp; Employment &nbsp; <i class="fa fa-map-marker fa-2x" style="color:mediumorchid"></i><br>
                              &nbsp; Health Care &nbsp; <i class="fa fa-map-marker fa-2x" style="color:orange"></i><br>
                              &nbsp; Civil Rights, Social Action & Adv. &nbsp; <i class="fa fa-map-marker fa-2x" style="color:gray"></i><br>
                              &nbsp; Volunt. Health Asso. & Medical Discipl. &nbsp; <i class="fa fa-map-marker fa-2x" style="color:dimgray"></i><br>
                              &nbsp; Unknown/Not Specified &nbsp; <i class="fa fa-map-marker fa-2x" style="color:steelblue"></i><br>
                              &nbsp; Housing & Shelter &nbsp; <i class="fa fa-map-marker fa-2x" style="color:darkolivegreen"></i><br>
                              &nbsp; Community Improv. & Capacity Building &nbsp; <i class="fa fa-map-marker fa-2x" style="color:darkcyan"></i><br>
                              &nbsp; Human Services &nbsp; <i class="fa fa-map-marker fa-2x" style="color:indigo"></i><br>
                              &nbsp; Religion-Related &nbsp; <i class="fa fa-map-marker fa-2x" style="color:magenta"></i><br>
                              &nbsp; Mutual & Member. Benefit &nbsp; <i class="fa fa-map-marker fa-2x" style="color:lightskyblue"></i><br>
                              &nbsp; Recreation & Sports &nbsp; <i class="fa fa-map-marker fa-2x" style="color:black"></i>
                </div>
                ''' 

m.get_root().html.add_child(folium.Element(legend_html))

m.save('hoboken_map.html')
w = sa.create_engine(r'sqlite:///D:\Program_practices\Charity\geotag.sqlite')
df=df.drop(columns=['location', 'point'])
df.to_sql('hoboken_map', w, if_exists='replace', index=False)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
